# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.xls = pd.ExcelFile('/content/WASTINNOVA DATA.xlsx')

# %%
df1=pd.read_excel(data,"HOUSEHOLD")
df2=pd.read_excel(data,"COMMERCIAL")
df3=pd.read_excel(data,"OTHERS")

# %%
df1.head()
# Out:
#    family size  monthly income  daily solid waste generation(in kg)  \
# 0            7           50670                                    3
# 1            7          135806                                    1
# 2            1          123248                                    2
# 3            6          137221                                    3
# 4            6          170863                                    3
#
#    kitchen waste  e-waste  non-recyclable
# 0              0        1               0
# 1              1        1               1
# 2              1        1               1
# 3              1        1               1
# 4              0        0               1

# %%
df1.corr()
# Out:
#                                      family size  monthly income  \
# family size                             1.000000        0.010875
# monthly income                          0.010875        1.000000
# daily solid waste generation(in kg)    -0.029602        0.009395
# kitchen waste                           0.008604        0.035308
# e-waste                                 0.017460       -0.017874
# non-recyclable                          0.007744        0.020744
#
#                                      daily solid waste generation(in kg)  \
# family size                                                    -0.029602
# monthly income                                                  0.009395
# daily solid waste generation(in kg)                             1.000000
# kitchen waste                                                  -0.008902
# e-waste                                                         0.003348
# non-recyclable                                                 -0.021463
#
#                                      kitchen waste   e-waste  non-recyclable
# family size                               0.008604  0.017460        0.007744
# monthly income                            0.035308 -0.017874        0.020744
# daily solid waste generation(in kg)      -0.008902  0.003348       -0.021463
# kitchen waste                             1.000000  0.004515        0.018535
# e-waste                                   0.004515  1.000000        0.000516
# non-recyclable                            0.018535  0.000516        1.000000

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range =(0, 1))

# %%
df1.iloc[:, 1:2].values
# Out:
# array([[ 50670],
#        [135806],
#        [123248],
#        ...,
#        [ 43040],
#        [166632],
#        [ 74332]])

# %%
x1=min_max_scaler.fit_transform(df1.iloc[:, 1:2].values)
x1
# Out:
# array([[0.23444164],
#        [0.70232469],
#        [0.63330952],
#        ...,
#        [0.19250934],
#        [0.87173555],
#        [0.3644812 ]])

# %%
df1["monthly income"]=x1
df1.head()
# Out:
#    family size  monthly income  daily solid waste generation(in kg)  \
# 0            7        0.234442                                    3
# 1            7        0.702325                                    1
# 2            1        0.633310                                    2
# 3            6        0.710101                                    3
# 4            6        0.894988                                    3
#
#    kitchen waste  e-waste  non-recyclable
# 0              0        1               0
# 1              1        1               1
# 2              1        1               1
# 3              1        1               1
# 4              0        0               1

# %%
remove=["daily solid waste generation(in kg)"]
X=df1.drop(remove,axis=1)

# %%
y=df1["daily solid waste generation(in kg)"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1339, 5) (660, 5) (1339,) (660,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
test_data_Y=lr.predict(X_test)
test_data_Y

# %%
from sklearn import metrics
mse=metrics.mean_absolute_error(y_test,test_data_Y)

# %%
print(mse)
from math import *
rmse=sqrt(mse)
print(rmse)
# Out:
# 0.6871163297080225
# 0.8289248034098283

# %%
df2.head()
# Out:
#   type_of_place  average_customer_count(daily)  scale_of_business  \
# 0         hotel                            436                  2
# 1        market                            234                  1
# 2          shop                            103                  0
# 3          shop                            201                  0
# 4         hotel                            423                  1
#
#    daily solid waste generation(in kg)  kitchen waste  e-waste  non-recyclable
# 0                                  457              0        1               1
# 1                                   85              0        1               1
# 2                                   82              1        1               1
# 3                                  185              1        1               1
# 4                                  117              1        1               0

# %%
df2=pd.get_dummies(df2)

# %%
df2.corr()
# Out:
#                                      average_customer_count(daily)  \
# average_customer_count(daily)                             1.000000
# scale_of_business                                         0.005097
# daily solid waste generation(in kg)                      -0.001623
# kitchen waste                                            -0.029314
# e-waste                                                  -0.018352
# non-recyclable                                            0.026517
# type_of_place_hotel                                       0.010192
# type_of_place_market                                     -0.013641
# type_of_place_shop                                        0.002516
#
#                                      scale_of_business  \
# average_customer_count(daily)                 0.005097
# scale_of_business                             1.000000
# daily solid waste generation(in kg)          -0.027087
# kitchen waste                                 0.020663
# e-waste                                       0.042534
# non-recyclable                                0.062000
# type_of_place_hotel                           0.005167
# type_of_place_market                          0.018717
# type_of_place_shop                           -0.021885
#
#                                      daily solid waste generation(in kg)  \
# average_customer_count(daily)                                  -0.001623
# scale_of_business                                              -0.027087
# daily solid waste generation(in kg)                             1.000000
# kitchen waste                                                  -0.038011
# e-waste                                                         0.035530
# non-recyclable                                                 -0.039193
# type_of_place_hotel                                             0.068151
# type_of_place_market                                            0.005098
# type_of_place_shop                                             -0.070200
#
#                                      kitchen waste   e-waste  non-recyclable  \
# average_customer_count(daily)            -0.029314 -0.018352        0.026517
# scale_of_business                         0.020663  0.042534        0.062000
# daily solid waste generation(in kg)      -0.038011  0.035530       -0.039193
# kitchen waste                             1.000000 -0.015342       -0.003592
# e-waste                                  -0.015342  1.000000        0.033556
# non-recyclable                           -0.003592  0.033556        1.000000
# type_of_place_hotel                      -0.028314  0.031157       -0.024100
# type_of_place_market                      0.072252 -0.075241       -0.056255
# type_of_place_shop                       -0.038030  0.037995        0.074025
#
#                                      type_of_place_hotel  \
# average_customer_count(daily)                   0.010192
# scale_of_business                               0.005167
# daily solid waste generation(in kg)             0.068151
# kitchen waste                                  -0.028314
# e-waste                                         0.031157
# non-recyclable                                 -0.024100
# type_of_place_hotel                             1.000000
# type_of_place_market                           -0.427056
# type_of_place_shop                             -0.576628
#
#                                      type_of_place_market  type_of_place_shop
# average_customer_count(daily)                   -0.013641            0.002516
# scale_of_business                                0.018717           -0.021885
# daily solid waste generation(in kg)              0.005098           -0.070200
# kitchen waste                                    0.072252           -0.038030
# e-waste                                         -0.075241            0.037995
# non-recyclable                                  -0.056255            0.074025
# type_of_place_hotel                             -0.427056           -0.576628
# type_of_place_market                             1.000000           -0.492505
# type_of_place_shop                              -0.492505            1.000000

# %%
remove=["daily solid waste generation(in kg)"]
X2=df2.drop(remove,axis=1)
X2
# Out:
#      average_customer_count(daily)  scale_of_business  kitchen waste  e-waste  \
# 0                              436                  2              0        1
# 1                              234                  1              0        1
# 2                              103                  0              1        1
# 3                              201                  0              1        1
# 4                              423                  1              1        1
# ..                             ...                ...            ...      ...
# 994                            179                  2              1        1
# 995                            246                  2              1        1
# 996                            331                  1              0        1
# 997                            312                  1              0        0
# 998                            142                  2              0        1
#
#      non-recyclable  type_of_place_hotel  type_of_place_market  \
# 0                 1                    1                     0
# 1                 1                    0                     1
# 2                 1                    0                     0
# 3                 1                    0                     0
# 4                 0                    1                     0
# ..              ...                  ...                   ...
# 994               0                    1                     0
# 995               0                    0                     1
# 996               0                    0                     1
# 997               1                    0                     0
# 998               1                    1                     0
#
#      type_of_place_shop
# 0                     0
# 1                     0
# 2                     1
# 3                     1
# 4                     0
# ..                  ...
# 994                   0
# 995                   0
# 996                   0
# 997                   1
# 998                   0
#
# [999 rows x 8 columns]

# %%
y2=df2["daily solid waste generation(in kg)"]

# %%
from sklearn.model_selection import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.33)
print(X2_train.shape, X2_test.shape, y2_train.shape, y2_test.shape)
# Out:
# (669, 6) (330, 6) (669,) (330,)

# %%
X2_test=pd.get_dummies(X2_test)

# %%
from sklearn.linear_model import LinearRegression
lr2 = LinearRegression()
lr2.fit(X2,y2)
# Out:
# LinearRegression()

# %%
test_data_Y2=lr2.predict(X2_test)
test_data_Y2

# %%
df3.head()
# Out:
#    MEDICAL  EDUCATIONAL  OFFICE  HEAD COUNT  \
# 0        1            0       1         333
# 1        0            1       0         354
# 2        0            0       1         316
# 3        0            0       1         150
# 4        0            1       0         351
#
#    daily solid waste generation(in kg)  kitchen waste  e-waste  non-recyclable
# 0                                  457              0        0               0
# 1                                  254              1        1               0
# 2                                  272              0        1               1
# 3                                  281              1        1               0
# 4                                  253              1        0               0

# %%
df3.corr()
# Out:
#                                       MEDICAL  EDUCATIONAL    OFFICE  \
# MEDICAL                              1.000000    -0.333096  0.007909
# EDUCATIONAL                         -0.333096     1.000000 -0.825854
# OFFICE                               0.007909    -0.825854  1.000000
# HEAD COUNT                           0.171106     0.002707  0.007724
# daily solid waste generation(in kg)  0.181633    -0.347172  0.348038
# kitchen waste                       -0.120756    -0.066136  0.040826
# e-waste                             -0.116230     0.021904  0.070986
# non-recyclable                       0.256606    -0.157992  0.040826
#
#                                      HEAD COUNT  \
# MEDICAL                                0.171106
# EDUCATIONAL                            0.002707
# OFFICE                                 0.007724
# HEAD COUNT                             1.000000
# daily solid waste generation(in kg)    0.064939
# kitchen waste                         -0.197528
# e-waste                               -0.283264
# non-recyclable                        -0.022799
#
#                                      daily solid waste generation(in kg)  \
# MEDICAL                                                         0.181633
# EDUCATIONAL                                                    -0.347172
# OFFICE                                                          0.348038
# HEAD COUNT                                                      0.064939
# daily solid waste generation(in kg)                             1.000000
# kitchen waste                                                  -0.116827
# e-waste                                                         0.007346
# non-recyclable                                                  0.043886
#
#                                      kitchen waste   e-waste  non-recyclable
# MEDICAL                                  -0.120756 -0.116230        0.256606
# EDUCATIONAL                              -0.066136  0.021904       -0.157992
# OFFICE                                    0.040826  0.070986        0.040826
# HEAD COUNT                               -0.197528 -0.283264       -0.022799
# daily solid waste generation(in kg)      -0.116827  0.007346        0.043886
# kitchen waste                             1.000000  0.206456        0.025974
# e-waste                                   0.206456  1.000000       -0.035485
# non-recyclable                            0.025974 -0.035485        1.000000

# %%
remove=["daily solid waste generation(in kg)"]
X3=df3.drop(remove,axis=1)

# %%
y3=df3["daily solid waste generation(in kg)"]

# %%
from sklearn.model_selection import train_test_split
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.33)
print(X3_train.shape, X3_test.shape, y3_train.shape, y3_test.shape)
# Out:
# (33, 7) (17, 7) (33,) (17,)

# %%
from sklearn.linear_model import LinearRegression
lr3 = LinearRegression()
lr3.fit(X3,y3)
# Out:
# LinearRegression()

# %%
test_data_Y3=lr3.predict(X3_test)
test_data_Y3
# Out:
# array([338.290765  , 332.03968937, 334.57092317, 327.85939026,
#        336.22523106, 356.89608525, 325.70545475, 335.91088348,
#        360.11763219, 280.67663524, 361.22674166, 325.01123176,
#        367.41353386, 372.40166442, 335.27237868, 297.62260711,
#        255.27370822])

# %%
import pickle

# %%
pickle.dump(lr,open("model1.pkl","wb"))
pickle.dump(lr,open("model2.pkl","wb"))
pickle.dump(lr,open("model3.pkl","wb"))
